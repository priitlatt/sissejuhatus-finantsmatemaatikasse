# %% [markdown]
# # MTMM.00.195 Sissejuhatus finantsmatemaatikasse #
#
# ## 2. kodutöö - Priit Lätt ##

# %% [markdown]
# <br>
# Impordime edaspidises vajaminevad moodulid:
#  * `datetime` - kuupäevade formaatimiseks,
#  * `numpy` - vektorarvutuse jaoks,
#  * `matplotlib` - jooniste tegemiseks,
#  * `HTML` - algandmete tabelina kuvamiseks.

# %%
import datetime

from IPython.display import HTML
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Loeme algandmed sisse failist `tallink.csv` ning salvestame nad listi `data`.

# %%
data = []

with open('tallink.csv') as f:
    header_string = next(f)
    for line in f:
        data.append(line.strip().split(','))

headers = {k.strip().lower(): i for i, k in 
           enumerate(header_string.split(','))}

# %% [markdown]
# Kuvame algandmed `HTML` tabelina.

# %%
table = "<table>{headers}{rows}</table>"
table_headers, table_rows = "", ""

for header in header_string.split(','):
    table_headers += "<th>{}</th>".format(header)

for row in data:
    columns = map(lambda v: "<td>{}</td>".format(v), row)
    table_rows += "<tr>{}</tr>".format(''.join(columns))
    
HTML(table.format(headers=table_headers, rows=table_rows))
# Out:
# <table><th>Date</th><th>Average Price</th><th>Open Price</th><th>High Price</th><th>Low Price</th><th>Last close Price</th><th>Last Price</th><th>Last Price (adjusted)</th><th>AdjustmentFactor</th><th>Price Change(%)</th><th>Best bid</th><th>Best ask</th><th>Trades</th><th>Volume</th><th>Turnover</th><th>CCY
# </th><tr><td>14.10.2013</td><td>0.951</td><td>0.951</td><td>0.960</td><td>0.950</td><td>0.954</td><td>0.960</td><td>0.960</td><td>1.0000000000</td><td>0.63%</td><td>0.952</td><td>0.960</td><td>56</td><td>433419</td><td>412318.22</td><td>EUR</td></tr><tr><td>15.10.2013</td><td>0.951</td><td>0.952</td><td>0.955</td><td>0.950</td><td>0.960</td><td>0.950</td><td>0.950</td><td>1.0000000000</td><td>-1.04%</td><td>0.950</td><td>0.951</td><td>38</td><td>282072</td><td>268556.75</td><td>EUR</td></tr><tr><td>16.10.2013</td><td>0.951</td><td>0.950</td><td>0.952</td><td>0.950</td><td>0.950</td><td>0.951</td><td>0.951</td><td>1.0000000000</td><td>0.11%</td><td>0.950</td><td>0.957</td><td>33</td><td>596048</td><td>566835.35</td><td>EUR</td></tr><tr><td>17.10.2013</td><td>0.951</td><td>0.960</td><td>0.960</td><td>0.951</td><td>0.951</td><td>0.951</td><td>0.951</td><td>1.0000000000</td><td>0.00%</td><td>0.942</td><td>0.952</td><td>14</td><td>466309</td><td>443461.41</td><td>EUR</td></tr><tr><td>18.10.2013</td><td>0.952</td><td>0.951</td><td>0.954</td><td>0.951</td><td>0.951</td><td>0.952</td><td>0.952</td><td>1.0000000000</td><td>0.11%</td><td>0.952</td><td>0.955</td><td>19</td><td>437222</td><td>416137.29</td><td>EUR</td></tr><tr><td>21.10.2013</td><td>0.952</td><td>0.952</td><td>0.952</td><td>0.952</td><td>0.952</td><td>0.952</td><td>0.952</td><td>1.0000000000</td><td>0.00%</td><td>0.952</td><td>0.953</td><td>28</td><td>406131</td><td>386636.71</td><td>EUR</td></tr><tr><td>22.10.2013</td><td>0.944</td><td>0.953</td><td>0.953</td><td>0.940</td><td>0.952</td><td>0.940</td><td>0.940</td><td>1.0000000000</td><td>-1.26%</td><td>0.940</td><td>0.956</td><td>22</td><td>205940</td><td>194412.20</td><td>EUR</td></tr><tr><td>23.10.2013</td><td>0.955</td><td>0.952</td><td>0.959</td><td>0.952</td><td>0.940</td><td>0.955</td><td>0.955</td><td>1.0000000000</td><td>1.60%</td><td>0.955</td><td>0.958</td><td>23</td><td>99035</td><td>94536.86</td><td>EUR</td></tr><tr><td>24.10.2013</td><td>0.963</td><td>0.959</td><td>0.972</td><td>0.959</td><td>0.955</td><td>0.972</td><td>0.972</td><td>1.0000000000</td><td>1.78%</td><td>0.965</td><td>0.972</td><td>46</td><td>283090</td><td>272616.51</td><td>EUR</td></tr><tr><td>25.10.2013</td><td>0.964</td><td>0.972</td><td>0.972</td><td>0.962</td><td>0.972</td><td>0.962</td><td>0.962</td><td>1.0000000000</td><td>-1.03%</td><td>0.961</td><td>0.962</td><td>19</td><td>39590</td><td>38171.54</td><td>EUR</td></tr><tr><td>28.10.2013</td><td>0.962</td><td>0.961</td><td>0.964</td><td>0.961</td><td>0.962</td><td>0.962</td><td>0.962</td><td>1.0000000000</td><td>0.00%</td><td>0.962</td><td>0.963</td><td>22</td><td>33322</td><td>32061.66</td><td>EUR</td></tr><tr><td>29.10.2013</td><td>0.963</td><td>0.962</td><td>0.965</td><td>0.961</td><td>0.962</td><td>0.965</td><td>0.965</td><td>1.0000000000</td><td>0.31%</td><td>0.961</td><td>0.965</td><td>18</td><td>137461</td><td>132380.65</td><td>EUR</td></tr><tr><td>30.10.2013</td><td>0.963</td><td>0.965</td><td>0.965</td><td>0.961</td><td>0.965</td><td>0.963</td><td>0.963</td><td>1.0000000000</td><td>-0.21%</td><td>0.961</td><td>0.963</td><td>9</td><td>11101</td><td>10689.21</td><td>EUR</td></tr><tr><td>31.10.2013</td><td>0.960</td><td>0.961</td><td>0.964</td><td>0.960</td><td>0.963</td><td>0.963</td><td>0.963</td><td>1.0000000000</td><td>0.00%</td><td>0.961</td><td>0.963</td><td>13</td><td>85444</td><td>82040.21</td><td>EUR</td></tr><tr><td>01.11.2013</td><td>0.963</td><td>0.961</td><td>0.964</td><td>0.960</td><td>0.963</td><td>0.964</td><td>0.964</td><td>1.0000000000</td><td>0.10%</td><td>0.964</td><td>0.968</td><td>14</td><td>262950</td><td>253117.25</td><td>EUR</td></tr><tr><td>04.11.2013</td><td>0.966</td><td>0.965</td><td>0.969</td><td>0.965</td><td>0.964</td><td>0.967</td><td>0.967</td><td>1.0000000000</td><td>0.31%</td><td>0.967</td><td>0.968</td><td>24</td><td>61707</td><td>59627.74</td><td>EUR</td></tr><tr><td>05.11.2013</td><td>0.961</td><td>0.963</td><td>0.965</td><td>0.960</td><td>0 ...

# %% [markdown]
# Koostame andmete põhjal kuupäevade järjendi `dates` ja hindade järjendi `prices`.

# %%
dates = []
for line in data:
    date_string = line[headers['date']]
    date = datetime.date(*reversed(map(int, date_string.split('.'))))
    dates.append(date)

prices = np.array(
    map(float, (line[headers['open price']] for line in data))
)

# %% [markdown]
# Määrame alghinnaks `S0` viimase teadaoleva hinna.

# %%
S0 = prices[-1]

# %% [markdown]
# Arvutame aktsiahinna muutude põhjal $\mu$ ja salvestame selle muutujasse `mu`.

# %%
changes_in_percentage = np.array(
    map(float, (line[headers['price change(%)']][:-1] for line in data))
)
mu = np.average(changes_in_percentage) / 100

# %% [markdown]
# Leiame aktsiahinna muutused päevade lõikes ja salvestame nad järjendisse `changes`.

# %%
changes = prices[:-1] - prices[1:]

# %% [markdown]
# Joonestame algandmed graafikule. Esimesel graafikul on toodud **Tallinki** aktsia hind ning teisel aktsiahinna muutused päevade lõikes.

# %%
plt.figure(figsize=(20, 14))
plt.rcParams['font.size'] = 16

plt.figure(1)

plt.subplot(211)
plt.xlabel('Aeg')
plt.ylabel('Hind (EUR)')
plt.title('Tallink Grupp aktsia hind')
plt.plot(dates, prices)

plt.subplot(212)
plt.xlabel('Aeg')
plt.ylabel('Muutus (EUR)')
plt.title('Tallink Grupp aktsiahinna muutused')
plt.plot(dates[1:], changes)

plt.show()

# %% [markdown]
# Leiame muutuste põhjal standardhälbe $\Sigma$ ning salvestame ta muutujasse `sigma` ning defineerime simulatsioonide arvu `n = 10`.

# %%
sigma = np.std(changes)
N = 10

# %% [markdown]
# Teostame simulatsioonid ja salvestame nad järjendisse `simulations`.

# %%
simulations = []

for i in range(N):
    rand = np.random.randn(1, len(prices))[0]
    dS = sigma*prices*rand + mu*prices
    S = [S0]
    for ds in dS:
        S.append(S[-1] + ds)
    simulations.append(S)

# %% [markdown]
# Kanname simulatsioonide tulemused ühele graafikule.

# %%
plt.figure(figsize=(20, 12))
plt.rcParams['font.size'] = 20

plt.xlabel('Aeg')
plt.ylabel('Hind (EUR)')
plt.title('Tallink Grupp aktsiahinna simulatsioon')

for i, sim in enumerate(simulations):
    plt.plot(sim, label="Simulatsioon nr %d" % (i+1))

plt.legend(loc='best')
plt.show()

# %% [markdown]
# Joonestame selguse mõttes simulatsioonid välja ka eraldi teljestikes.

# %%
rows = int(N/2) + N % 2
columns = 2

plt.figure(figsize=(16, rows*4))
plt.rcParams['font.size'] = 10

plt.figure(1)
for i, S in enumerate(simulations):
    plt.subplot(rows, columns, i+1)
    plt.title("Simulatsioon %d" % (i+1))
    plt.plot(S)
plt.show()
